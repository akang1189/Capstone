# %%
import yfinance as yf
import pandas as pd

SPY = yf.download('SPY')
SPY
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   25.799770
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   25.983273
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   26.038315
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   26.313566
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   26.423655
# ...                ...         ...         ...         ...         ...
# 2021-08-11  443.820007  443.880005  442.619995  443.779999  443.779999
# 2021-08-12  443.619995  445.260010  442.660004  445.109985  445.109985
# 2021-08-13  445.589996  445.940002  445.070007  445.920013  445.920013
# 2021-08-16  444.529999  447.109985  442.869995  446.970001  446.970001
# 2021-08-17  444.239990  444.959991  440.850006  444.040009  444.040009
#
#               Volume
# Date
# ...

# %%
SPY.to_csv('df.csv')

# %%
df = pd.read_csv('./df.csv')

# %%
df['date'] = pd.to_datetime(df['Date'])
df.sort_values(by='date', inplace = True)

# %%
import matplotlib.pyplot as plt

df['close'].plot(figsize=(14,5),legend=True,linestyle='--',marker='o');
plt.legend(['Price'])
plt.title('SPY')        
plt.xlabel('Date')        
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1993-01-29   43.968750   43.968750   43.750000   43.937500   25.799770
# 1     1993-02-01   43.968750   44.250000   43.968750   44.250000   25.983273
# 2     1993-02-02   44.218750   44.375000   44.125000   44.343750   26.038315
# 3     1993-02-03   44.406250   44.843750   44.375000   44.812500   26.313566
# 4     1993-02-04   44.968750   45.093750   44.468750   45.000000   26.423655
# ...          ...         ...         ...         ...         ...         ...
# 7185  2021-08-11  443.820007  443.880005  442.619995  443.779999  443.779999
# 7186  2021-08-12  443.619995  445.260010  442.660004  445.109985  445.109985
# 7187  2021-08-13  445.589996  445.940002  445.070007  445.920013  445.920013
# 7188  2021-08-16  444.529999  447.109985  442.869995  446.970001  446.970001
# 7189  2021-08-17  444.239990  444.959991  440.850006  444.040009  444.040009
#
#         Volume       date
# ...

# %%
df.set_index('date', drop=True, inplace=True)

# %%
df
# Out:
#                   Date        Open        High         Low       Close  \
# date
# 1993-01-29  1993-01-29   43.968750   43.968750   43.750000   43.937500
# 1993-02-01  1993-02-01   43.968750   44.250000   43.968750   44.250000
# 1993-02-02  1993-02-02   44.218750   44.375000   44.125000   44.343750
# 1993-02-03  1993-02-03   44.406250   44.843750   44.375000   44.812500
# 1993-02-04  1993-02-04   44.968750   45.093750   44.468750   45.000000
# ...                ...         ...         ...         ...         ...
# 2021-08-11  2021-08-11  443.820007  443.880005  442.619995  443.779999
# 2021-08-12  2021-08-12  443.619995  445.260010  442.660004  445.109985
# 2021-08-13  2021-08-13  445.589996  445.940002  445.070007  445.920013
# 2021-08-16  2021-08-16  444.529999  447.109985  442.869995  446.970001
# 2021-08-17  2021-08-17  444.239990  444.959991  440.850006  444.040009
#
#              Adj Close    Volume
# date
# 1993-01-29   25.799770   1003200
# 1993-02-01   25.983273    480500
# ...

# %%
df.drop(columns='Date', inplace=True)

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   25.799770
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   25.983273
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   26.038315
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   26.313566
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   26.423655
# ...                ...         ...         ...         ...         ...
# 2021-08-11  443.820007  443.880005  442.619995  443.779999  443.779999
# 2021-08-12  443.619995  445.260010  442.660004  445.109985  445.109985
# 2021-08-13  445.589996  445.940002  445.070007  445.920013  445.920013
# 2021-08-16  444.529999  447.109985  442.869995  446.970001  446.970001
# 2021-08-17  444.239990  444.959991  440.850006  444.040009  444.040009
#
#               Volume
# date
# 1993-01-29   1003200
# 1993-02-01    480500
# 1993-02-02    201300
# ...

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close   Volume
# date
# 1993-01-29  43.96875  43.96875  43.75000  43.93750  25.799770  1003200
# 1993-02-01  43.96875  44.25000  43.96875  44.25000  25.983273   480500
# 1993-02-02  44.21875  44.37500  44.12500  44.34375  26.038315   201300
# 1993-02-03  44.40625  44.84375  44.37500  44.81250  26.313566   529400
# 1993-02-04  44.96875  45.09375  44.46875  45.00000  26.423655   531500

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# date
# 2021-08-11  443.820007  443.880005  442.619995  443.779999  443.779999
# 2021-08-12  443.619995  445.260010  442.660004  445.109985  445.109985
# 2021-08-13  445.589996  445.940002  445.070007  445.920013  445.920013
# 2021-08-16  444.529999  447.109985  442.869995  446.970001  446.970001
# 2021-08-17  444.239990  444.959991  440.850006  444.040009  444.040009
#
#               Volume
# date
# 2021-08-11  44034300
# 2021-08-12  38909400
# 2021-08-13  39388300
# 2021-08-16  73740000
# 2021-08-17  92444500

# %%
df.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
columns=['open','high','low','close','adjusted close','volume']
df.columns=(columns)

# %%
df
# Out:
#                   open        high         low       close  adjusted close  \
# date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500       25.799770
# 1993-02-01   43.968750   44.250000   43.968750   44.250000       25.983273
# 1993-02-02   44.218750   44.375000   44.125000   44.343750       26.038315
# 1993-02-03   44.406250   44.843750   44.375000   44.812500       26.313566
# 1993-02-04   44.968750   45.093750   44.468750   45.000000       26.423655
# ...                ...         ...         ...         ...             ...
# 2021-08-11  443.820007  443.880005  442.619995  443.779999      443.779999
# 2021-08-12  443.619995  445.260010  442.660004  445.109985      445.109985
# 2021-08-13  445.589996  445.940002  445.070007  445.920013      445.920013
# 2021-08-16  444.529999  447.109985  442.869995  446.970001      446.970001
# 2021-08-17  444.239990  444.959991  440.850006  444.040009      444.040009
#
#               volume
# date
# 1993-01-29   1003200
# ...

# %%
df.shape
# Out:
# (7190, 6)

# %%
df.info
# Out:
# <bound method DataFrame.info of                   open        high         low       close  adjusted close  \
# date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500       25.799770
# 1993-02-01   43.968750   44.250000   43.968750   44.250000       25.983273
# 1993-02-02   44.218750   44.375000   44.125000   44.343750       26.038315
# 1993-02-03   44.406250   44.843750   44.375000   44.812500       26.313566
# 1993-02-04   44.968750   45.093750   44.468750   45.000000       26.423655
# ...                ...         ...         ...         ...             ...
# 2021-08-11  443.820007  443.880005  442.619995  443.779999      443.779999
# 2021-08-12  443.619995  445.260010  442.660004  445.109985      445.109985
# 2021-08-13  445.589996  445.940002  445.070007  445.920013      445.920013
# 2021-08-16  444.529999  447.109985  442.869995  446.970001      446.970001
# 2021-08-17  444.239990  444.959991  440.850006  444.040009      444.040009
#
#               volume
# date
# ...

# %%
SPY = yf.Ticker('SPY')
dfh = SPY.history(start="1980-01-01", end="2020-08-13")
dfh.head()
# Out:
#                  Open       High        Low      Close   Volume  Dividends  \
# Date
# 1993-01-29  25.818120  25.818120  25.689672  25.799770  1003200        0.0
# 1993-02-01  25.818125  25.983273  25.818125  25.983273   480500        0.0
# 1993-02-02  25.964916  26.056665  25.909866  26.038315   201300        0.0
# 1993-02-03  26.075019  26.331916  26.056669  26.313566   529400        0.0
# 1993-02-04  26.405305  26.478704  26.111709  26.423655   531500        0.0
#
#             Stock Splits
# Date
# 1993-01-29             0
# 1993-02-01             0
# 1993-02-02             0
# 1993-02-03             0
# 1993-02-04             0

# %%
df.head()
# Out:
#                 open      high       low     close  adjusted close   volume
# date
# 1993-01-29  43.96875  43.96875  43.75000  43.93750       25.799770  1003200
# 1993-02-01  43.96875  44.25000  43.96875  44.25000       25.983273   480500
# 1993-02-02  44.21875  44.37500  44.12500  44.34375       26.038315   201300
# 1993-02-03  44.40625  44.84375  44.37500  44.81250       26.313566   529400
# 1993-02-04  44.96875  45.09375  44.46875  45.00000       26.423655   531500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7190 entries, 1993-01-29 to 2021-08-17
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   open            7190 non-null   float64
#  1   high            7190 non-null   float64
#  2   low             7190 non-null   float64
#  3   close           7190 non-null   float64
#  4   adjusted close  7190 non-null   float64
#  5   volume          7190 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 393.2 KB

# %%
df
# Out:
#                   open        high         low       close  adjusted close  \
# date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500       25.799770
# 1993-02-01   43.968750   44.250000   43.968750   44.250000       25.983273
# 1993-02-02   44.218750   44.375000   44.125000   44.343750       26.038315
# 1993-02-03   44.406250   44.843750   44.375000   44.812500       26.313566
# 1993-02-04   44.968750   45.093750   44.468750   45.000000       26.423655
# ...                ...         ...         ...         ...             ...
# 2021-08-11  443.820007  443.880005  442.619995  443.779999      443.779999
# 2021-08-12  443.619995  445.260010  442.660004  445.109985      445.109985
# 2021-08-13  445.589996  445.940002  445.070007  445.920013      445.920013
# 2021-08-16  444.529999  447.109985  442.869995  446.970001      446.970001
# 2021-08-17  444.239990  444.959991  440.850006  444.040009      444.040009
#
#               volume
# date
# 1993-01-29   1003200
# ...

# %%
SPY.info
# Out:
# {'exchange': 'PCX',
#  'shortName': 'SPDR S&P 500',
#  'longName': 'SPDR S&P 500 ETF Trust',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'ETF',
#  'symbol': 'SPY',
#  'messageBoardId': 'finmb_6160262',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': None,
#  'beta3Year': 1,
#  'profitMargins': None,
#  'enterpriseToEbitda': None,
#  '52WeekChange': None,
#  'morningStarRiskRating': None,
#  'forwardEps': None,
#  'revenueQuarterlyGrowth': None,
#  'fundInceptionDate': 727660800,
#  'annualReportExpenseRatio': None,
#  'totalAssets': 374031319040,
#  'bookValue': None,
#  'fundFamily': 'SPDR State Street Global Advisors',
#  'lastFiscalYearEnd': None,
#  'netIncomeToCommon': None,
#  'trailingEps': None,
#  'lastDividendValue': None,
#  'SandP52WeekChange': None,
#  'priceToBook': None,
#  'nextFiscalYearEnd': None,
# ...

# %%
df['totalAssets'] = SPY.info['totalAssets']
df['yield'] = SPY.info['yield']
df['trailingAnnualDividendYield'] = SPY.info['trailingAnnualDividendYield']
df['trailingAnnualDividendRate'] = SPY.info['trailingAnnualDividendRate']
df['trailingPE'] = SPY.info['trailingPE']
df['fiftyTwoWeekHigh'] = SPY.info['fiftyTwoWeekHigh']
df['fiftyTwoWeekLow'] = SPY.info['fiftyTwoWeekLow']
df['regularMarketVolume'] = SPY.info['regularMarketVolume']
df['averageVolume'] = SPY.info['averageVolume']
df['averageDailyVolume10Day'] = SPY.info['averageDailyVolume10Day']
df['threeYearAverageReturn'] = SPY.info['threeYearAverageReturn']
df['fiveYearAverageReturn'] = SPY.info['fiveYearAverageReturn']
df['twoHundredDayAverage'] = SPY.info['twoHundredDayAverage']
df['fiftyDayAverage'] = SPY.info['fiftyDayAverage']

# %%
df
# Out:
#                   open        high         low       close  adjusted close  \
# date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500       25.799770
# 1993-02-01   43.968750   44.250000   43.968750   44.250000       25.983273
# 1993-02-02   44.218750   44.375000   44.125000   44.343750       26.038315
# 1993-02-03   44.406250   44.843750   44.375000   44.812500       26.313566
# 1993-02-04   44.968750   45.093750   44.468750   45.000000       26.423655
# ...                ...         ...         ...         ...             ...
# 2021-08-11  443.820007  443.880005  442.619995  443.779999      443.779999
# 2021-08-12  443.619995  445.260010  442.660004  445.109985      445.109985
# 2021-08-13  445.589996  445.940002  445.070007  445.920013      445.920013
# 2021-08-16  444.529999  447.109985  442.869995  446.970001      446.970001
# 2021-08-17  444.239990  444.959991  440.850006  444.040009      444.040009
#
# ...

# %%
df.head()
# Out:
#                 open      high       low     close  adjusted close   volume  \
# date
# 1993-01-29  43.96875  43.96875  43.75000  43.93750       25.799770  1003200
# 1993-02-01  43.96875  44.25000  43.96875  44.25000       25.983273   480500
# 1993-02-02  44.21875  44.37500  44.12500  44.34375       26.038315   201300
# 1993-02-03  44.40625  44.84375  44.37500  44.81250       26.313566   529400
# 1993-02-04  44.96875  45.09375  44.46875  45.00000       26.423655   531500
#
#              totalAssets  yield  trailingAnnualDividendYield  \
# date
# 1993-01-29  374031319040  0.013                     0.012446
# 1993-02-01  374031319040  0.013                     0.012446
# 1993-02-02  374031319040  0.013                     0.012446
# 1993-02-03  374031319040  0.013                     0.012446
# 1993-02-04  374031319040  0.013                     0.012446
#
#             trailingAnnualDividendRate  trailingPE  fiftyTwoWeekHigh  \
# date
# ...

# %%
df.tail()
# Out:
#                   open        high         low       close  adjusted close  \
# date
# 2021-08-11  443.820007  443.880005  442.619995  443.779999      443.779999
# 2021-08-12  443.619995  445.260010  442.660004  445.109985      445.109985
# 2021-08-13  445.589996  445.940002  445.070007  445.920013      445.920013
# 2021-08-16  444.529999  447.109985  442.869995  446.970001      446.970001
# 2021-08-17  444.239990  444.959991  440.850006  444.040009      444.040009
#
#               volume   totalAssets  yield  trailingAnnualDividendYield  \
# date
# 2021-08-11  44034300  374031319040  0.013                     0.012446
# 2021-08-12  38909400  374031319040  0.013                     0.012446
# 2021-08-13  39388300  374031319040  0.013                     0.012446
# 2021-08-16  73740000  374031319040  0.013                     0.012446
# 2021-08-17  92444500  374031319040  0.013                     0.012446
#
#             trailingAnnualDividendRate  trailingPE  fiftyTwoWeekHigh  \
# ...

# %%
df.shape
# Out:
# (7190, 20)

# %%
df.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'adjusted close', 'volume',
#        'totalAssets', 'yield', 'trailingAnnualDividendYield',
#        'trailingAnnualDividendRate', 'trailingPE', 'fiftyTwoWeekHigh',
#        'fiftyTwoWeekLow', 'regularMarketVolume', 'averageVolume',
#        'averageDailyVolume10Day', 'threeYearAverageReturn',
#        'fiveYearAverageReturn', 'twoHundredDayAverage', 'fiftyDayAverage'],
#       dtype='object')

# %%
df
# Out:
#                   open        high         low       close  adjusted close  \
# date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500       25.799770
# 1993-02-01   43.968750   44.250000   43.968750   44.250000       25.983273
# 1993-02-02   44.218750   44.375000   44.125000   44.343750       26.038315
# 1993-02-03   44.406250   44.843750   44.375000   44.812500       26.313566
# 1993-02-04   44.968750   45.093750   44.468750   45.000000       26.423655
# ...                ...         ...         ...         ...             ...
# 2021-08-11  443.820007  443.880005  442.619995  443.779999      443.779999
# 2021-08-12  443.619995  445.260010  442.660004  445.109985      445.109985
# 2021-08-13  445.589996  445.940002  445.070007  445.920013      445.920013
# 2021-08-16  444.529999  447.109985  442.869995  446.970001      446.970001
# 2021-08-17  444.239990  444.959991  440.850006  444.040009      444.040009
#
# ...

# %%
#drop first row
#outside source
#dropping if missing values is greater than 10%
df = df.loc[:, df.isna().sum()/df.shape[0] <= 0.1]
df = df.dropna(axis=0,how='all',subset=df.columns[1:])

# %%
df
# Out:
#                   open        high         low       close  adjusted close  \
# date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500       25.799770
# 1993-02-01   43.968750   44.250000   43.968750   44.250000       25.983273
# 1993-02-02   44.218750   44.375000   44.125000   44.343750       26.038315
# 1993-02-03   44.406250   44.843750   44.375000   44.812500       26.313566
# 1993-02-04   44.968750   45.093750   44.468750   45.000000       26.423655
# ...                ...         ...         ...         ...             ...
# 2021-08-11  443.820007  443.880005  442.619995  443.779999      443.779999
# 2021-08-12  443.619995  445.260010  442.660004  445.109985      445.109985
# 2021-08-13  445.589996  445.940002  445.070007  445.920013      445.920013
# 2021-08-16  444.529999  447.109985  442.869995  446.970001      446.970001
# 2021-08-17  444.239990  444.959991  440.850006  444.040009      444.040009
#
# ...

# %%
df.tail()
# Out:
#                   open        high         low       close  adjusted close  \
# date
# 2021-08-11  443.820007  443.880005  442.619995  443.779999      443.779999
# 2021-08-12  443.619995  445.260010  442.660004  445.109985      445.109985
# 2021-08-13  445.589996  445.940002  445.070007  445.920013      445.920013
# 2021-08-16  444.529999  447.109985  442.869995  446.970001      446.970001
# 2021-08-17  444.239990  444.959991  440.850006  444.040009      444.040009
#
#               volume   totalAssets  yield  trailingAnnualDividendYield  \
# date
# 2021-08-11  44034300  374031319040  0.013                     0.012446
# 2021-08-12  38909400  374031319040  0.013                     0.012446
# 2021-08-13  39388300  374031319040  0.013                     0.012446
# 2021-08-16  73740000  374031319040  0.013                     0.012446
# 2021-08-17  92444500  374031319040  0.013                     0.012446
#
#             trailingAnnualDividendRate  trailingPE  fiftyTwoWeekHigh  \
# ...

# %%
df.to_csv('df.csv')
